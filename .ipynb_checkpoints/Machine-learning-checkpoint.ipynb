# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %%
customerData = pd.read_csv('dataset\customerData_Clean.csv')

# %% [markdown]
# ## Showing the data

# %%
customerData
# Out:
#       Unnamed: 0  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0              0        1957  Graduation         Single  58138.0        0
# 1              1        1954  Graduation         Single  46344.0        1
# 2              2        1965  Graduation        Married  71613.0        0
# 3              3        1984  Graduation        Married  26646.0        1
# 4              4        1981         PhD        Married  58293.0        1
# ...          ...         ...         ...            ...      ...      ...
# 2161        2161        1967  Graduation        Married  61223.0        0
# 2162        2162        1946         PhD        Married  64014.0        2
# 2163        2163        1981  Graduation       Divorced  56981.0        0
# 2164        2164        1956      Master        Married  69245.0        0
# 2165        2165        1954         PhD        Married  52869.0        1
#
#       Teenhome  Recency  MntWines  MntFruits  ...  NumWebPurchases  \
# 0            0       58       635         88  ...                8
# 1            1       38        11          1  ...                1
# 2            0       26       426         49  ...                8
# 3            0       26        11          4  ...                2
# 4            0       94       173         43  ...                5
# ...        ...      ...       ...        ...  ...              ...
# 2161         1       46       709         43  ...                9
# 2162         1       56       406          0  ...                8
# 2163         0       91       908         48  ...                2
# 2164         1        8       428         30  ...                6
# 2165         1       40        84          3  ...                3
#
#       NumCatalogPurchases  NumStorePurchases  NumWebVisitsMonth  \
# 0                      10                  4                  7
# 1                       1                  2                  5
# 2                       2                 10                  4
# 3                       0                  4                  6
# 4                       3                  6                  5
# ...                   ...                ...                ...
# 2161                    3                  4                  5
# 2162                    2                  5                  7
# 2163                    3                 13                  6
# 2164                    5                 10                  3
# 2165                    1                  4                  7
#
#       MntGroceryProducts  TotalPurchase  AcceptedCmp  YearRange  TotalChild  \
# 0                    806             25            1       1950           0
# 1                      9              6            0       1950           2
# 2                    287             21            0       1960           0
# 3                     34              8            0       1980           1
# 4                    207             19            0       1980           1
# ...                  ...            ...          ...        ...         ...
# 2161                 267             18            0       1960           1
# 2162                  30             22            1       1940           3
# 2163                 297             19            1       1980           0
# 2164                 324             23            0       1950           1
# 2165                  66             11            1       1950           2
#
#       HaveChild
# 0             0
# 1             1
# 2             0
# 3             1
# 4             1
# ...         ...
# 2161          1
# 2162          1
# 2163          0
# 2164          1
# 2165          1
#
# [2166 rows x 25 columns]

# %% [markdown]
# ### Importing Machine Learning modules

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

gbc = GradientBoostingClassifier(n_estimators=500,learning_rate=0.05,random_state=1)

# %% [markdown]
# ## Poisson Regression

# %% [markdown]
# ### Predicting TotalPurchase
# Predictors : Education, Marital_Status, Income, TotalChild, HaveChild, NumWebVisitsMonth, YearRange

# %%
df_train = pd.read_csv(r'dataset\new_train_data.csv')
df_cv = pd.read_csv(r'dataset\splitted_cv_data.csv')
df_test =  pd.read_csv(r'dataset\new_test_data.csv')

# %%
from patsy import dmatrices
import statsmodels.api as sm

# mask = np.random.rand(len(customerData)) < 0.8
# TotalPurchase ~ Year_Birth + Education + Marital_Status + Kidhome + Teenhome + Income + Recency + YearRange + HaveChild + Complain
# TotalPurchase ~ Income  + TotalChild + Teenhome + Kidhome + Year_Birth + Marital_Status
expr = """TotalPurchase ~ Education + Marital_Status + Income + TotalChild + HaveChild + NumWebVisitsMonth + YearRange"""

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['TotalPurchase']
fig = plt.figure(figsize = (30, 12))
fig.suptitle('Predicted versus actual TotalPurchase')
predicted, = plt.plot(X_test.index, predicted_counts, 'go-', label='Predicted counts')
actual, = plt.plot(X_test.index, actual_counts, 'ro-', label='Actual counts')
plt.legend(handles=[predicted, actual])
plt.show()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          TotalPurchase   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1739
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -5448.6
# Date:                Fri, 22 Apr 2022   Deviance:                       3205.1
# Time:                        10:58:45   Pearson chi2:                 3.19e+03
# No. Iterations:                     5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     6.9604      1.066      6.530      0.000       4.871       9.049
# Education[T.Basic]           -0.1148      0.065     -1.768      0.077      -0.242       0.012
# Education[T.Graduation]       0.0038      0.023      0.165      0.869      -0.041       0.049
# Education[T.Master]           0.0092      0.026      0.350      0.727      -0.042       0.061
# Education[T.PhD]             -0.0064      0.025     -0.255      0.799      -0.055       0.043
# Marital_Status[T.Married]     0.0039      0.018      0.214      0.831      -0.032       0.040
# Marital_Status[T.Single]     -0.0146      0.022     -0.667      0.504      -0.057       0.028
# Income                     2.294e-05   4.49e-07     51.148      0.000    2.21e-05    2.38e-05
# TotalChild                   -0.1239      0.015     -8.316      0.000      -0.153      -0.095
# HaveChild                     0.1964      0.025      7.983      0.000       0.148       0.245
# NumWebVisitsMonth             0.0591      0.004     15.324      0.000       0.052       0.067
# YearRange                    -0.0030      0.001     -5.517      0.000      -0.004      -0.002
# =============================================================================================
#           mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    26.388076  0.464097      25.493962      27.313548
# 1    10.055206  0.171758       9.724139      10.397544
# 2    13.487277  0.274573      12.959719      14.036311
# 3    14.100879  0.168731      13.774020      14.435495
# 4    10.152666  0.156820       9.849911      10.464728
# ..         ...       ...            ...            ...
# 432  18.086657  0.220269      17.660049      18.523571
# 433  17.798409  0.539891      16.771083      18.888665
# 434  15.194853  0.369970      14.486755      15.937562
# 435  20.007834  0.402730      19.233865      20.812948
# 436  15.142779  0.275723      14.611902      15.692944
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
print("For test data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['TotalPurchase']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# For test data:
# Mean Squared Error (MSE) 	: 26.377814060878787
# Root Mean Squared Error (RMSE) 	: 5.135933611416602
# Explained Variance (R^2) 	: 0.551062143523237
#
# For train data:
# Mean Squared Error (MSE) 	: 26.989875903137545
# Root Mean Squared Error (RMSE) 	: 5.195178139692377
# Explained Variance (R^2) 	: 0.5259304067207635

# %% [markdown]
# The Poisson Regression works relatively well for predicting TotalPurchase (with an R^2 value of 0.54)

# %% [markdown]
# #### The importance of the Income variable: removing Income

# %%
expr = """TotalPurchase ~ Education + Marital_Status + TotalChild + HaveChild + NumWebVisitsMonth + YearRange"""

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['TotalPurchase']
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          TotalPurchase   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1740
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -6782.0
# Date:                Fri, 22 Apr 2022   Deviance:                       5871.9
# Time:                        10:58:46   Pearson chi2:                 5.88e+03
# No. Iterations:                     5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    16.4661      1.051     15.666      0.000      14.406      18.526
# Education[T.Basic]           -0.6302      0.064     -9.873      0.000      -0.755      -0.505
# Education[T.Graduation]       0.0689      0.023      2.994      0.003       0.024       0.114
# Education[T.Master]           0.0641      0.026      2.436      0.015       0.013       0.116
# Education[T.PhD]              0.0961      0.025      3.836      0.000       0.047       0.145
# Marital_Status[T.Married]    -0.0165      0.018     -0.907      0.364      -0.052       0.019
# Marital_Status[T.Single]     -0.0559      0.022     -2.566      0.010      -0.099      -0.013
# TotalChild                   -0.1672      0.015    -11.141      0.000      -0.197      -0.138
# HaveChild                     0.1007      0.024      4.113      0.000       0.053       0.149
# NumWebVisitsMonth            -0.0451      0.003    -13.867      0.000      -0.051      -0.039
# YearRange                    -0.0069      0.001    -12.814      0.000      -0.008      -0.006
# =============================================================================================
#           mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    15.507739  0.234967      15.053982      15.975172
# 1    10.931840  0.183987      10.577115      11.298462
# 2    11.257215  0.228436      10.818275      11.713965
# 3    14.140144  0.167641      13.815361      14.472562
# 4    13.201421  0.183821      12.846011      13.566664
# ..         ...       ...            ...            ...
# 432  15.843774  0.191718      15.472435      16.224025
# 433  12.216033  0.362470      11.525867      12.947526
# 434  14.344167  0.344454      13.684691      15.035425
# 435  18.481413  0.366731      17.776431      19.214353
# 436  13.480757  0.246175      13.006795      13.971989
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['TotalPurchase']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 51.2276705652343
# Root Mean Squared Error (RMSE) 	: 7.157350806355261
# Explained Variance (R^2) 	: 0.12797680165544112
#
# For train data:
# Mean Squared Error (MSE) 	: 47.50293015426503
# Root Mean Squared Error (RMSE) 	: 6.8922369484997414
# Explained Variance (R^2) 	: 0.16562436749898113

# %% [markdown]
# By removing the income variable, the Poisson Regression performs significantly worse, with an R^2 value of 0.13, making it the best predictor. This pattern can be observd in later models as well.

# %% [markdown]
# #### The worse predicting variable: removing Education

# %%
expr = """TotalPurchase ~ Marital_Status + Income + TotalChild + HaveChild + NumWebVisitsMonth + YearRange"""

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['TotalPurchase']
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          TotalPurchase   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1743
# Model Family:                 Poisson   Df Model:                            7
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -5450.8
# Date:                Fri, 22 Apr 2022   Deviance:                       3209.5
# Time:                        10:58:47   Pearson chi2:                 3.19e+03
# No. Iterations:                     4
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     6.9845      1.055      6.623      0.000       4.918       9.051
# Marital_Status[T.Married]     0.0034      0.018      0.185      0.853      -0.032       0.039
# Marital_Status[T.Single]     -0.0155      0.022     -0.710      0.478      -0.058       0.027
# Income                     2.311e-05   4.38e-07     52.719      0.000    2.22e-05     2.4e-05
# TotalChild                   -0.1225      0.015     -8.239      0.000      -0.152      -0.093
# HaveChild                     0.1976      0.025      8.036      0.000       0.149       0.246
# NumWebVisitsMonth             0.0591      0.004     15.313      0.000       0.051       0.067
# YearRange                    -0.0030      0.001     -5.602      0.000      -0.004      -0.002
# =============================================================================================
#           mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    26.375467  0.423301      25.558725      27.218308
# 1    10.000577  0.156447       9.698600      10.311957
# 2    13.438115  0.257024      12.943683      13.951434
# 3    14.039583  0.144151      13.759877      14.324976
# 4    10.085248  0.142237       9.810286      10.367917
# ..         ...       ...            ...            ...
# 432  18.048700  0.188081      17.683807      18.421123
# 433  18.006967  0.518900      17.018129      19.053262
# 434  15.113214  0.356625      14.430158      15.828602
# 435  19.892103  0.298720      19.315156      20.486284
# 436  15.267118  0.230614      14.821747      15.725871
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['TotalPurchase']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 26.263185831050198
# Root Mean Squared Error (RMSE) 	: 5.124762026772579
# Explained Variance (R^2) 	: 0.5530068107257408
#
# For train data:
# Mean Squared Error (MSE) 	: 27.05370051534936
# Root Mean Squared Error (RMSE) 	: 5.201317190419111
# Explained Variance (R^2) 	: 0.5248093453249627

# %% [markdown]
# By repeatedly removing and comparing variables, we found out that the Education variable is the 'worst' predictor. However, the change in R^2 value is not significant

# %% [markdown]
# ### 2. Predicting MntGroceryProducts

# %%
from patsy import dmatrices
import statsmodels.api as sm

expr = """MntGroceryProducts ~ Education + Marital_Status + Income + TotalChild + HaveChild + NumWebVisitsMonth + YearRange"""

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['MntGroceryProducts']
fig = plt.figure(figsize = (30, 12))
fig.suptitle('Predicted versus actual MntGroceryProducts')
predicted, = plt.plot(X_test.index, predicted_counts, 'go-', label='Predicted counts')
actual, = plt.plot(X_test.index, actual_counts, 'ro-', label='Actual counts')
plt.legend(handles=[predicted, actual])
plt.show()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     MntGroceryProducts   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1739
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -70141.
# Date:                Fri, 22 Apr 2022   Deviance:                   1.2923e+05
# Time:                        10:58:47   Pearson chi2:                 1.37e+05
# No. Iterations:                     6
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     1.0309      0.245      4.203      0.000       0.550       1.512
# Education[T.Basic]           -0.3298      0.028    -11.631      0.000      -0.385      -0.274
# Education[T.Graduation]       0.0410      0.006      6.826      0.000       0.029       0.053
# Education[T.Master]          -0.0836      0.007    -12.027      0.000      -0.097      -0.070
# Education[T.PhD]             -0.1850      0.007    -27.737      0.000      -0.198      -0.172
# Marital_Status[T.Married]     0.0163      0.005      3.394      0.001       0.007       0.026
# Marital_Status[T.Single]      0.0622      0.006     11.177      0.000       0.051       0.073
# Income                     4.317e-05   1.32e-07    326.008      0.000    4.29e-05    4.34e-05
# TotalChild                   -0.4294      0.006    -72.327      0.000      -0.441      -0.418
# HaveChild                    -0.0802      0.008     -9.879      0.000      -0.096      -0.064
# NumWebVisitsMonth             0.0184      0.001     17.647      0.000       0.016       0.020
# YearRange                     0.0010      0.000      8.243      0.000       0.001       0.001
# =============================================================================================
#            mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    326.104844  1.540421     323.099607     329.138033
# 1     45.389787  0.289248      44.826396      45.960259
# 2     80.007838  0.539219      78.957939      81.071699
# 3    125.658674  0.462117     124.756197     126.567680
# 4     72.368480  0.349394      71.686910      73.056529
# ..          ...       ...            ...            ...
# 432  206.131350  0.705987     204.752275     207.519714
# 433   79.884364  0.934747      78.073142      81.737605
# 434  292.247399  1.844483     288.654547     295.884971
# 435  245.464589  1.349064     242.834662     248.122999
# 436   76.636441  0.495036      75.672304      77.612862
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['MntGroceryProducts']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 30530.208191754937
# Root Mean Squared Error (RMSE) 	: 174.72895636314817
# Explained Variance (R^2) 	: 0.614025963324961
#
# For train data:
# Mean Squared Error (MSE) 	: 23917.609022274755
# Root Mean Squared Error (RMSE) 	: 154.6531894991977
# Explained Variance (R^2) 	: 0.6826081436250401

# %% [markdown]
# The Poisson Regression model works even better in predicting MntGroceryProducts, with a relatively high R^2 value of 0.66

# %% [markdown]
# #### The worst predicting variables: (All variables except Income perform somewhat equally well)

# %%
from patsy import dmatrices
import statsmodels.api as sm

expr = """MntGroceryProducts ~ Education + Marital_Status + Income + TotalChild + HaveChild + NumWebVisitsMonth """

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['MntGroceryProducts']
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:     MntGroceryProducts   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1740
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -70175.
# Date:                Fri, 22 Apr 2022   Deviance:                   1.2930e+05
# Time:                        10:58:48   Pearson chi2:                 1.37e+05
# No. Iterations:                     6
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     3.0495      0.014    225.158      0.000       3.023       3.076
# Education[T.Basic]           -0.3258      0.028    -11.492      0.000      -0.381      -0.270
# Education[T.Graduation]       0.0404      0.006      6.737      0.000       0.029       0.052
# Education[T.Master]          -0.0861      0.007    -12.400      0.000      -0.100      -0.072
# Education[T.PhD]             -0.1879      0.007    -28.220      0.000      -0.201      -0.175
# Marital_Status[T.Married]     0.0187      0.005      3.902      0.000       0.009       0.028
# Marital_Status[T.Single]      0.0698      0.005     12.726      0.000       0.059       0.081
# Income                     4.314e-05   1.32e-07    325.686      0.000    4.29e-05    4.34e-05
# TotalChild                   -0.4320      0.006    -72.891      0.000      -0.444      -0.420
# HaveChild                    -0.0780      0.008     -9.624      0.000      -0.094      -0.062
# NumWebVisitsMonth             0.0185      0.001     17.730      0.000       0.016       0.021
# =============================================================================================
#            mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    330.637090  1.459684     327.788504     333.510432
# 1     45.023488  0.283560      44.471137      45.582699
# 2     80.568285  0.538393      79.519934      81.630456
# 3    124.897109  0.450428     124.017400     125.783058
# 4     71.225777  0.315663      70.609768      71.847161
# ..          ...       ...            ...            ...
# 432  206.898129  0.702338     205.526142     208.279275
# 433   81.219799  0.935970      79.405893      83.075142
# 434  286.891235  1.692826     283.592468     290.228373
# 435  248.326842  1.318128     245.756751     250.923811
# 436   77.355879  0.491760      76.398028      78.325740
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['MntGroceryProducts']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 30476.862340657146
# Root Mean Squared Error (RMSE) 	: 174.57623647179804
# Explained Variance (R^2) 	: 0.6147380262327762
#
# For train data:
# Mean Squared Error (MSE) 	: 23932.856889395098
# Root Mean Squared Error (RMSE) 	: 154.70247861425847
# Explained Variance (R^2) 	: 0.6824058011230543

# %% [markdown]
# Similar to the previous model, none of the variables affect the model significantly except Income

# %% [markdown]
# ### 3. Predicting MntWines

# %%
from patsy import dmatrices
import statsmodels.api as sm

expr = """MntWines ~ Education + Marital_Status + Income + TotalChild + HaveChild + NumWebVisitsMonth + YearRange"""

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['MntWines']
fig = plt.figure(figsize = (30, 12))
fig.suptitle('Predicted versus actual MntWines')
predicted, = plt.plot(X_test.index, predicted_counts, 'go-', label='Predicted counts')
actual, = plt.plot(X_test.index, actual_counts, 'ro-', label='Actual counts')
plt.legend(handles=[predicted, actual])
plt.show()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               MntWines   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1739
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.0344e+05
# Date:                Fri, 22 Apr 2022   Deviance:                   1.9557e+05
# Time:                        10:58:48   Pearson chi2:                 1.99e+05
# No. Iterations:                     8
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    11.5422      0.221     52.192      0.000      11.109      11.976
# Education[T.Basic]           -2.3865      0.086    -27.836      0.000      -2.555      -2.219
# Education[T.Graduation]       0.2623      0.006     43.147      0.000       0.250       0.274
# Education[T.Master]           0.4557      0.007     69.130      0.000       0.443       0.469
# Education[T.PhD]              0.5327      0.006     84.717      0.000       0.520       0.545
# Marital_Status[T.Married]    -0.0251      0.004     -6.351      0.000      -0.033      -0.017
# Marital_Status[T.Single]     -0.0565      0.005    -11.775      0.000      -0.066      -0.047
# Income                     5.572e-05   1.09e-07    512.612      0.000    5.55e-05    5.59e-05
# TotalChild                   -0.3941      0.004    -97.373      0.000      -0.402      -0.386
# HaveChild                     0.3282      0.006     54.957      0.000       0.317       0.340
# NumWebVisitsMonth             0.1630      0.001    193.336      0.000       0.161       0.165
# YearRange                    -0.0052      0.000    -46.104      0.000      -0.005      -0.005
# =============================================================================================
#            mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    825.335657  2.969191     819.536619     831.175730
# 1     76.697566  0.368097      75.979491      77.422428
# 2    155.376830  0.793106     153.830121     156.939092
# 3    184.119915  0.562086     183.021535     185.224887
# 4     84.633629  0.352161      83.946212      85.326675
# ..          ...       ...            ...            ...
# 432  323.840661  0.901449     322.078665     325.612296
# 433  346.411313  2.760938     341.042020     351.865139
# 434  297.126610  1.618751     293.970794     300.316304
# 435  467.050237  2.054065     463.041645     471.093532
# 436  262.145858  1.159886     259.882352     264.429079
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['MntWines']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 47595.86445810742
# Root Mean Squared Error (RMSE) 	: 218.1647644742556
# Explained Variance (R^2) 	: 0.5717570891851436
#
# For train data:
# Mean Squared Error (MSE) 	: 49756.75887434214
# Root Mean Squared Error (RMSE) 	: 223.0622309454071
# Explained Variance (R^2) 	: 0.5606727257715242

# %% [markdown]
# For predicting MntWines, the model performs somewhat as well as predicting TotalPurchase, though the model might improve if the outlier is removed (where the predicted value of 3000+ is much higher than the actual value)

# %% [markdown]
# #### The worse predicting variable: Education, Marital_Status, HaveChild (not a lot tho)

# %%
from patsy import dmatrices
import statsmodels.api as sm

expr = """MntWines ~ Income + TotalChild + NumWebVisitsMonth """

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['MntWines']
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               MntWines   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1747
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.1435e+05
# Date:                Fri, 22 Apr 2022   Deviance:                   2.1737e+05
# Time:                        10:58:49   Pearson chi2:                 2.21e+05
# No. Iterations:                     5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             1.6256      0.010    169.692      0.000       1.607       1.644
# Income             5.648e-05   1.05e-07    537.964      0.000    5.63e-05    5.67e-05
# TotalChild           -0.1930      0.002    -80.969      0.000      -0.198      -0.188
# NumWebVisitsMonth     0.1747      0.001    214.630      0.000       0.173       0.176
# =====================================================================================
#            mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    794.830529  1.982300     790.954772     798.725277
# 1     98.580259  0.328482      97.938544      99.226179
# 2    197.507165  0.582882     196.368036     198.652903
# 3    191.171430  0.392020     190.404627     191.941320
# 4     91.641575  0.282001      91.090526      92.195957
# ..          ...       ...            ...            ...
# 432  318.473644  0.493314     317.508233     319.441990
# 433  359.404717  1.822888     355.849621     362.995330
# 434  361.992265  1.040691     359.958285     364.037738
# 435  353.294920  0.764484     351.799732     354.796462
# 436  232.296452  0.664487     230.997725     233.602481
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['MntWines']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 53919.8993851107
# Root Mean Squared Error (RMSE) 	: 232.20658772978578
# Explained Variance (R^2) 	: 0.5148575490924322
#
# For train data:
# Mean Squared Error (MSE) 	: 54756.220074351455
# Root Mean Squared Error (RMSE) 	: 234.00047024386822
# Explained Variance (R^2) 	: 0.5165299859448004

# %% [markdown]
# The 'worst' variables for predicting MntWines are Education, Marital_Status, and HaveChild, even though it still is not very significant

# %% [markdown]
# ### Predicting MntGoldProds

# %%
expr = """MntGoldProds ~ Education + Marital_Status + Income + TotalChild + HaveChild + NumWebVisitsMonth + YearRange"""

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['MntGoldProds']
fig = plt.figure(figsize = (30, 12))
fig.suptitle('Predicted versus actual MntGoldProds')
predicted, = plt.plot(X_test.index, predicted_counts, 'go-', label='Predicted counts')
actual, = plt.plot(X_test.index, actual_counts, 'ro-', label='Actual counts')
plt.legend(handles=[predicted, actual])
plt.show()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           MntGoldProds   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1739
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -33041.
# Date:                Fri, 22 Apr 2022   Deviance:                       57631.
# Time:                        10:58:49   Pearson chi2:                 6.87e+04
# No. Iterations:                     5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     8.3701      0.609     13.735      0.000       7.176       9.564
# Education[T.Basic]            0.1140      0.036      3.184      0.001       0.044       0.184
# Education[T.Graduation]       0.0228      0.013      1.779      0.075      -0.002       0.048
# Education[T.Master]          -0.2012      0.015    -13.232      0.000      -0.231      -0.171
# Education[T.PhD]             -0.5462      0.015    -36.015      0.000      -0.576      -0.517
# Marital_Status[T.Married]    -0.1042      0.010     -9.979      0.000      -0.125      -0.084
# Marital_Status[T.Single]     -0.0626      0.012     -5.027      0.000      -0.087      -0.038
# Income                     2.875e-05   2.69e-07    106.998      0.000    2.82e-05    2.93e-05
# TotalChild                   -0.3635      0.010    -34.737      0.000      -0.384      -0.343
# HaveChild                     0.2601      0.015     16.802      0.000       0.230       0.290
# NumWebVisitsMonth             0.0639      0.002     28.060      0.000       0.059       0.068
# YearRange                    -0.0032      0.000    -10.254      0.000      -0.004      -0.003
# =============================================================================================
#           mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    89.687599  0.911280      87.919190      91.491577
# 1    21.763737  0.247223      21.284544      22.253719
# 2    33.357255  0.432067      32.521078      34.214932
# 3    41.785924  0.295445      41.210856      42.369016
# 4    27.842667  0.258990      27.339655      28.354934
# ..         ...       ...            ...            ...
# 432  57.343021  0.402132      56.560249      58.136627
# 433  20.586040  0.446446      19.729358      21.479921
# 434  62.495069  0.859886      60.832246      64.203346
# 435  52.436426  0.639680      51.197546      53.705285
# 436  20.820884  0.274000      20.290719      21.364901
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['MntGoldProds']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 2276.859875591481
# Root Mean Squared Error (RMSE) 	: 47.71645288149027
# Explained Variance (R^2) 	: 0.19943732386904933
#
# For train data:
# Mean Squared Error (MSE) 	: 1886.6879470919118
# Root Mean Squared Error (RMSE) 	: 43.4360213082634
# Explained Variance (R^2) 	: 0.23646880169820017

# %% [markdown]
# Surprisingly, the Poisson Regression model performs the worst in predicting MntGoldProds.

# %% [markdown]
# #### The worse predicting variable: Marital_Status, HaveChild, YearRange (not very significant tho)

# %%
expr = """MntGoldProds ~ Education + Marital_Status + Income + TotalChild + HaveChild + NumWebVisitsMonth + YearRange"""

y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()

print(poisson_training_results.summary())

poisson_predictions = poisson_training_results.get_prediction(X_test)
#summary_frame() returns a pandas DataFrame
predictions_summary_frame = poisson_predictions.summary_frame()
print(predictions_summary_frame)

predicted_counts=predictions_summary_frame['mean']
actual_counts = y_test['MntGoldProds']
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           MntGoldProds   No. Observations:                 1751
# Model:                            GLM   Df Residuals:                     1739
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -33041.
# Date:                Fri, 22 Apr 2022   Deviance:                       57631.
# Time:                        10:58:50   Pearson chi2:                 6.87e+04
# No. Iterations:                     5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     8.3701      0.609     13.735      0.000       7.176       9.564
# Education[T.Basic]            0.1140      0.036      3.184      0.001       0.044       0.184
# Education[T.Graduation]       0.0228      0.013      1.779      0.075      -0.002       0.048
# Education[T.Master]          -0.2012      0.015    -13.232      0.000      -0.231      -0.171
# Education[T.PhD]             -0.5462      0.015    -36.015      0.000      -0.576      -0.517
# Marital_Status[T.Married]    -0.1042      0.010     -9.979      0.000      -0.125      -0.084
# Marital_Status[T.Single]     -0.0626      0.012     -5.027      0.000      -0.087      -0.038
# Income                     2.875e-05   2.69e-07    106.998      0.000    2.82e-05    2.93e-05
# TotalChild                   -0.3635      0.010    -34.737      0.000      -0.384      -0.343
# HaveChild                     0.2601      0.015     16.802      0.000       0.230       0.290
# NumWebVisitsMonth             0.0639      0.002     28.060      0.000       0.059       0.068
# YearRange                    -0.0032      0.000    -10.254      0.000      -0.004      -0.003
# =============================================================================================
#           mean   mean_se  mean_ci_lower  mean_ci_upper
# 0    89.687599  0.911280      87.919190      91.491577
# 1    21.763737  0.247223      21.284544      22.253719
# 2    33.357255  0.432067      32.521078      34.214932
# 3    41.785924  0.295445      41.210856      42.369016
# 4    27.842667  0.258990      27.339655      28.354934
# ..         ...       ...            ...            ...
# 432  57.343021  0.402132      56.560249      58.136627
# 433  20.586040  0.446446      19.729358      21.479921
# 434  62.495069  0.859886      60.832246      64.203346
# 435  52.436426  0.639680      51.197546      53.705285
# 436  20.820884  0.274000      20.290719      21.364901
#
# [437 rows x 4 columns]

# %%
plt.clf()
fig = plt.figure()
fig.suptitle('Scatter plot of Actual versus Predicted counts')
plt.scatter(x=predicted_counts, y=actual_counts, marker='.')
plt.xlabel('Predicted counts')
plt.ylabel('Actual counts')
plt.show()

from sklearn.metrics import mean_squared_error
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts, predicted_counts))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts, predicted_counts)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts, predicted_counts))

poisson_predictions_train = poisson_training_results.get_prediction(X_train)
predictions_summary_frame_train = poisson_predictions_train.summary_frame()
predicted_counts_train = predictions_summary_frame_train['mean']
actual_counts_train = y_train['MntGoldProds']
print("")
print("For train data:")
print("Mean Squared Error (MSE) \t:", mean_squared_error(actual_counts_train, predicted_counts_train))
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mean_squared_error(actual_counts_train, predicted_counts_train)))
print("Explained Variance (R^2) \t:", explained_variance_score(actual_counts_train, predicted_counts_train))
# Out:
# Mean Squared Error (MSE) 	: 2276.859875591481
# Root Mean Squared Error (RMSE) 	: 47.71645288149027
# Explained Variance (R^2) 	: 0.19943732386904933
#
# For train data:
# Mean Squared Error (MSE) 	: 1886.6879470919118
# Root Mean Squared Error (RMSE) 	: 43.4360213082634
# Explained Variance (R^2) 	: 0.23646880169820017

# %% [markdown]
# As before, the 'worst' variables are not very significant.

# %%
print("HI")
